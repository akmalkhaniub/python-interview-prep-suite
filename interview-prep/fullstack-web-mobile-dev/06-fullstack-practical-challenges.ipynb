# %% [markdown]
# # 06 - Full-Stack Practical Challenges
#
# This notebook contains core building blocks for Full-Stack developers working with Web (React), Mobile (React Native), and Backend (Node.js).

# %% [markdown]
# ## 1. React Native: Basic Layout
#
# **Task:** Create a simple profile screen layout with an image and text.

# %%
/*
import React from 'react';
import { View, Text, Image, StyleSheet, SafeAreaView } from 'react-native';

const ProfileScreen = () => {
  return (
    <SafeAreaView style={styles.container}>
      <View style={styles.card}>
        <Image 
          source={{ uri: 'https://via.placeholder.com/150' }} 
          style={styles.avatar} 
        />
        <Text style={styles.name}>John Doe</Text>
        <Text style={styles.bio}>Full-Stack Developer | Mobile Enthusiast</Text>
      </View>
    </SafeAreaView>
  );
};

const styles = StyleSheet.create({
  container: { flex: 1, backgroundColor: '#f5f5f5' },
  card: { alignItems: 'center', padding: 20, backgroundColor: 'white', margin: 20, borderRadius: 10 },
  avatar: { width: 100, height: 100, borderRadius: 50 },
  name: { fontSize: 24, fontWeight: 'bold', marginTop: 10 },
  bio: { fontSize: 16, color: 'gray', textAlign: 'center' }
});
*/
print("React Native layout defined.")

# %% [markdown]
# ## 2. Backend: Express API with Validation
#
# **Task:** Create a POST endpoint for creating a user with basic error handling.

# %%
/*
const express = require('express');
const app = express();
app.use(express.json());

app.post('/api/users', (req, res) => {
  const { name, email } = req.body;

  // Basic validation
  if (!name || !email) {
    return res.status(400).json({ error: 'Name and email are required' });
  }

  try {
    // In a real app: await User.create({ name, email });
    res.status(201).json({ id: 1, name, email });
  } catch (err) {
    res.status(500).json({ error: 'Internal server error' });
  }
});
*/
print("Express API endpoint defined.")

# %% [markdown]
# ## 3. Database: SQL Join
#
# **Task:** Fetch all posts with their author names from a Postgres DB.

# %%
/*
SELECT 
  posts.id, 
  posts.title, 
  users.name AS author_name
FROM posts
JOIN users ON posts.author_id = users.id
ORDER BY posts.created_at DESC;
*/
print("SQL Join query defined.")
